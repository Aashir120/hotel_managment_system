# %%
import time
class hotelfarecal:

    def __init__(self,sub_total='',room_rent=0,game_bill=0,food_bill=0,laundary_bill=0,additional=0,name='',address='',cindate='',coutdate='',rno=0):
        print("____________________________________________")
        print("|                                           |")
        print("|    *****WELCOME TO MARIOTT HOTEL*****     |")
        print("|___________________________________________|")

        self.sub_total=sub_total

        self.food_bill=food_bill

        self.laundary_bill=laundary_bill

        self.game_bill=game_bill

        self.room_rent=room_rent
        self.additional=additional
        self.name=name
        self.address=address
        self.cindate=cindate
        self.coutdate=coutdate
        self.rno=rno
    
    def inputdata(self):
        self.rno=101
        self.name=input("\nEnter your name:")
        self.address=input("\nEnter your address:")
        self.cindate=input("\nEnter your check in date:")
        self.coutdate=input("\nEnter your checkout date:")
        self.rno+=1
        
    def roomrent(self):#sel1353

        print ("We have the following rooms for you:-")

        print ("1.  type A---->rs 6000 PN\-")

        print ("2.  type B---->rs 5000 PN\-")

        print ("3.  type C---->rs 4000 PN\-")

        print ("4.  type D---->rs 3000 PN\-")

        x=int(input("Enter Your Choice Please->"))

        n=int(input("For How Many Nights Did You Stay:"))

        if(x==1):

            print ("you have opted room type A")

            self.room_rent=6000*n

        elif (x==2):

            print ("you have opted room type B")

            self.room_rent=5000*n

        elif (x==3):

            print ("you have opted room type C")

            self.room_rent=4000*n

        elif (x==4):
            print ("you have opted room type D")

            self.room_rent=3000*n

        else:

            print ("please choose a room")

        print ("your room rent is =",self.room_rent,"\n")

    def restaurentbill(self):

        print("*****RESTAURANT MENU*****")

        print("1.water----->Rs20","2.tea----->Rs10","3.breakfast combo--->Rs90","4.lunch---->Rs110","5.dinner--->Rs150","6.Exit")


        while (1):

            c=int(input("Enter your choice:"))


            if (c==1):
                d=int(input("Enter the quantity:"))
                self.food_bill=self.food_bill+20*d

            elif (c==2):
                d=int(input("Enter the quantity:"))
                self.food_bill=self.food_bill+10*d

            elif (c==3):
                d=int(input("Enter the quantity:"))
                self.food_bill=self.food_bill+90*d

            elif (c==4):
                d=int(input("Enter the quantity:"))
                self.food_bill=self.food_bill+110*d

            elif (c==5):
                d=int(input("Enter the quantity:"))
                self.food_bill=self.food_bill+150*d

            elif (c==6):
                break;
            else:
                print("Invalid option")

        print ("Total food Cost=Rs",self.food_bill,"\n")

    def	laundrybill(self):
        print ("******LAUNDRY MENU*******")

        print ("1.Shorts----->Rs3","2.Trousers----->Rs4","3.Shirt--->Rs5","4.Jeans---->Rs6","5.Girlsuit--->Rs8","6.Exit")

        while (1):
            #brought to you by code-projects.org

            e=int(input("Enter your choice:"))

            if (e==1):
                f=int(input("Enter the quantity:"))
                self.laundary_bill=self.laundary_bill+3*f

            elif (e==2):
                f=int(input("Enter the quantity:"))
                self.laundary_bill=self.laundary_bill+4*f

            elif (e==3):
                f=int(input("Enter the quantity:"))
                self.laundary_bill=self.laundary_bill+5*f

            elif (e==4):
                f=int(input("Enter the quantity:"))
                self.laundary_bill=self.laundary_bill+6*f

            elif (e==5):
                f=int(input("Enter the quantity:"))
                self.laundary_bill=self.laundary_bill+8*f
            elif (e==6):
                break;
            else:

                print ("Invalid option")


        print ("Total Laundary Cost=Rs",self.laundary_bill,"\n")

    def gamebill(self):
        print ("******GAME MENU*******")

        print ("1.Table tennis----->Rs60","2.Bowling----->Rs80","3.Snooker--->Rs70","4.Video games---->Rs90","5.Pool--->Rs50==6","6.Exit")



        while (1):

            
            g=int(input("Enter your choice:"))


            if (g==1):
                h=int(input("No. of hours:"))
                self.game_bill=self.game_bill+60*h

            elif (g==2):
                h=int(input("No. of hours:"))
                self.game_bill=self.game_bill+80*h

            elif (g==3):
                h=int(input("No. of hours:"))
                self.game_bill=self.game_bill+70*h

            elif (g==4):
                h=int(input("No. of hours:"))
                self.game_bill=self.game_bill+90*h

            elif (g==5):
                h=int(input("No. of hours:"))
                self.game_bill=self.game_bill+50*h
            elif (g==6):
                break;

            else:

                print ("Invalid option")



        print ("Total Game Bill=Rs",self.game_bill,"\n")

    def display(self):
        print("========================================================")
        print("__________________________")
        print("|  *****HOTEL BILL******  |")
        print("|_________________________|")
        print ("Customer details:")
        print ("Customer name:",self.name)
        print ("Customer address:",self.address)
        print ("Check in date:",self.cindate)
        print ("Check out date",self.coutdate)
        print ("Room no.",self.rno)
        print ("Your Room rent is:",self.room_rent)
        print ("Your Food bill is:",self.food_bill)
        print ("Your laundary bill is:",self.laundary_bill)
        print ("Your Game bill is:",self.game_bill)
        print("________________________________________________________")

        self.sub_total=self.room_rent+self.laundary_bill+self.game_bill+self.food_bill
        
        if self.sub_total>=10000:
            self.additional = 1800
        elif self.sub_total >=5000:
            self.additional = 1000
        else:
            self.additional = 0
                
        print ("Your sub total bill is:",self.sub_total)
        print ("Additional Service Charges is",self.additional)
        print ("Your grandtotal bill is:",self.sub_total+self.additional)
        print("========================================================")
        

        
    def quit(self):
        print()
        print("________________________________________________________")
        print("|                                                       |")
        print("|                                                       |")
        print("|         =========THANKS FOR COMING=========           |")
        print("|                                                       |")
        print("|_______________________________________________________|")

        

        

def main():

    a=hotelfarecal()
    

    while (1):
        print("1.Enter Customer Data")
        
        print("2.Calculate room rent")

        print("3.Calculate restaurant bill")

        print("4.Calculate laundry bill")

        print("5.Calculate gamebill")

        print("6.Show total cost")

        print("7.EXIT")

        b=int(input("\nEnter your choice:"))
        if (b==1):
            
            time.sleep(2)
            a.inputdata()

        if (b==2):
            
            time.sleep(2)
            a.roomrent()

        if (b==3):

            time.sleep(2)
            a.restaurentbill()

        if (b==4):

            time.sleep(2)
            a.laundrybill()

        if (b==5):
            
            time.sleep(2)
            a.gamebill()

        if (b==6):

            time.sleep(2)
            a.display()

        if (b==7):
            
            time.sleep(2)
            a.quit()
            break



main()
# Out:
# ____________________________________________
# |                                           |
# |    *****WELCOME TO MARIOTT HOTEL*****     |
# |___________________________________________|
# 1.Enter Customer Data
# 2.Calculate room rent
# 3.Calculate restaurant bill
# 4.Calculate laundry bill
# 5.Calculate gamebill
# 6.Show total cost
# 7.EXIT
#
# Enter your choice:1
#
# Enter your name:aashir
#
# Enter your address:street 408
#
# Enter your check in date:20 jan
#
# Enter your checkout date:20 march
# 1.Enter Customer Data
# 2.Calculate room rent
# 3.Calculate restaurant bill
# 4.Calculate laundry bill
# 5.Calculate gamebill
# 6.Show total cost
# 7.EXIT
#
# Enter your choice:2
# We have the following rooms for you:-
# 1.  type A---->rs 6000 PN\-
# 2.  type B---->rs 5000 PN\-
# 3.  type C---->rs 4000 PN\-
# 4.  type D---->rs 3000 PN\-
# Enter Your Choice Please->1
# For How Many Nights Did You Stay:4
# you have opted room type A
# your room rent is = 24000
#
# 1.Enter Customer Data
# ...
